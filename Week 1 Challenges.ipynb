# %% [markdown]
# ### Starting the challenge!
# * Open up a new Jupyter Notebook using the command line
# * Read in the CSV file (using Pandas or CSV reader)

# %% [markdown]
# ### Task 0:
# Some of this age data doesn't make sense, there must have been an error in it. Filter out all the rows where the age is equal to zero. How many rows were removed?

# %%
df = df[df['Age'] > 0]

# %% [markdown]
# ### Task 1
# Create a new variable, age_group, that categorizes users as “<18”, “18-24”, “25-34”, “35-44”, “45-54”, “55-64” and “65+”.

# %%
bins = [0, 18, 25, 35, 45, 55, 65, 100]
group_names = ["<18", "18-24", "25-34", "35-44", "45-54", "55-64", "65+"]
df['age_group'] = pd.cut(df.Age, bins, labels=group_names)

# %%
pd.value_counts(df['age_group'])
# Out:
# 35-44    130
# 25-34    120
# 18-24     72
# 45-54     67
# <18       64
# 55-64     32
# 65+       12
# Name: age_group, dtype: int64

# %% [markdown]
# ### Task 2
# For a single day,
# Plot the distributions of number of impressions and click-through-rate

# %%
df
# Out:
#      Age  Clicks  Day  Gender  Impressions  Signed_In age_group
# 0     42       1    8       1            3          0     35-44
# 1     32       1   19       0            0          1     25-34
# 2     44       2   14       0            2          1     35-44
# 3     57       1   25       1            0          0     55-64
# 4     31       3    8       1            0          0     25-34
# 5     31       1   20       0            1          1     25-34
# 6     58       5   18       0            0          0     55-64
# 7     46       2   10       0            2          1     45-54
# 8     27       0    6       0            2          0     25-34
# 9     43       3   19       0            0          0     35-44
# 10    28       0   21       0            0          1     25-34
# 11    28       2   10       0            0          0     25-34
# 12    38       1   19       0            0          1     35-44
# 13     6       2   12       1            9          0       <18
# ...

# %% [markdown]
# ### Task 3
# Define a new variable to segment or categorize users based on their click behavior

# %% [markdown]
# ### Task 4
# Explore the data and make visual and quantitative comparisons across user segments / demographics

# %% [markdown]
# ### Task 5
# Create metrics/measurements/statistics that summarize the data

# %% [markdown]
# ### Task 6
# Now extend your analysis across days. Visualize metrics and distributions over time

# %% [markdown]
# ### Task 7
# Describe and interpret any patterns you find
