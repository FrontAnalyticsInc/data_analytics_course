# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
eng = create_engine("sqlite:///mysqlitedb.db")

# %%
df = pd.read_csv('/Users/dpl/Downloads/DOHMH_New_York_City_Restaurant_Inspection_Results.csv')

# %%
df.shape
# Out:
# (425768, 18)

# %%
df.to_sql('nyc_data', eng)
